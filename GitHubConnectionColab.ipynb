# %% [markdown]
# #Git Setting

# %% [markdown]
# ##Google Drive Mount
# Google Colab을 이용할 경우 구글 드라이브 마운트 필요

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Generating SSH Key
#
# 키를 만들어서 공개키를 GitHub에 등록했으면 다시 실하하면 안 됨.

# %%
# !ssh-keygen
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa
# Your public key has been saved in /root/.ssh/id_rsa.pub
# The key fingerprint is:
# SHA256:EubwArMAx1Z4VJv2uShGjDs+ZqxgbCdcIojc4qdodYU root@e701c8314bb2
# The key's randomart image is:
# +---[RSA 3072]----+
# |...+o..          |
# |..+ .  o         |
# |..o.. B          |
# |+..* E + .       |
# |++oo+ = S        |
# |= ++ o o .       |
# |.O+o+ . .        |
# |=oXo .           |
# |+=..             |
# +----[SHA256]-----+

# %%
cd ~/.ssh/
# Out:
# /root/.ssh

# %%
# !ls
# Out:
# id_rsa	id_rsa.pub

# %%
# !cat id_rsa.pub
# Out:
# ssh-rsa ... root@e701c8314bb2

# %% [markdown]
# GitHub 홈페이지 로그인 - Setting - SSH에 공개키(id_rsa.pub의 내용) 등록하기

# %% [markdown]
# Key File Backup

# %%
# !cp ~/.ssh/id_rsa /content/drive/MyDrive
# !cp ~/.ssh/id_rsa.pub /content/drive/MyDrive

# %% [markdown]
# ##SSH Setting
# 백업한 id_rsa 파일을 로컬에 저장해야 함

# %%
cd /content/drive/MyDrive/Colab
# Out:
# /content/drive/MyDrive/Colab

# %%
# !mkdir -p ~/.ssh/
# !cp id_rsa ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-133e47a51
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %% [markdown]
# ##Git Cloning

# %%
cd /content/drive/MyDrive/Colab
# Out:
# /content/drive/MyDrive/Colab

# %%
# !git clone git@github.com:w0v5eu8/GitHubConnection.git
# Out:
# Cloning into 'GitHubConnection'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %% [markdown]
# # Git Command
# Setting이 끝난 후 에는 아래를 이용하여 git 커맨드 실행
#
# 백업한 id_rsa 파일을 로컬에 저장해야 함

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab
# Out:
# /content/drive/MyDrive/Colab

# %%
# !mkdir -p ~/.ssh/
# !cp id_rsa ~/.ssh/
# !chmod 400 ~/.ssh/id_rsa
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# !ssh -T git@github.com
# Out:
# # github.com:22 SSH-2.0-6fdec156f
# Hi w0v5eu8! You've successfully authenticated, but GitHub does not provide shell access.

# %%
cd /content/drive/MyDrive/Colab/GitHubConnection
# Out:
# /content/drive/MyDrive/Colab/GitHubConnection

# %%
# !git config --local user.email 'w0v5eu8@gmail.com'
# !git config --local user.name 'w0v5eu8'

# %%
# !git add .
# !git commit -m 'commit'
# !git push
# Out:
# [main 9fc5d06] commit
#  2 files changed, 718 insertions(+)
#  create mode 100644 GitHubConnectionSageMaker.ipynb
#  create mode 100644 SageMakerPackagePesistentInstall.txt
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 4.81 KiB | 328.00 KiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# To github.com:w0v5eu8/GitHubConnection.git
#    76f85f8..9fc5d06  main -> main

# %%
# !git pull
# Out:
# Already up to date.
